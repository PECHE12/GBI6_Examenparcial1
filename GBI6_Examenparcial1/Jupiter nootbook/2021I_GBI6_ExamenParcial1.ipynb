# %% [markdown]
# <img src="https://www.ikiam.edu.ec/img/logo-ikiam-grey.png" width=300 height=240 />
#
# # EXAMEN PARCIAL 1
#
# ## GBI6-2021II: BIOINFORMÁTICA
#
# **Arcos López María Betsabé** <--- CAMBIE POR LOS QUE CORRESPONDA A SUS DATOS
#
# **11-01-2021**

# %% [markdown]
# <font color='red'>NO AGREGUE NUEVAS CELDAS, UTILICE ÚNICAMENTE LAS QUE ESTÁN CREADAS</font>

# %% [markdown]
# # 1. UNIX
#
# ## Ejercicio 1
# Seleccione la opción de código que imprime el directorio de trabajo actual
#
# a. $ get wd
#
# b. $ pwd
#
# c. $ touch pwd
#
# d. $ echo pwd
#
# Coloque aquí la captura de pantalla del ejercicio 1 (borre esta línea cuando finalice)
#
# <img src="https://github.com/PECHE12/GBI6_Examenparcial1/blob/main/GBI6_Examenparcial1/Data/EJERCICIO1.jpeg "      ancho=600 alto=450 />
#
# ![EJERCICIO1.jpeg](attachment:1a57b9e6-04e8-46f6-badf-8c0c1ca88fc5.jpeg)
#
# ## Ejercicio 2
# Para esta pregunta debe realizar previamente lo siguiente:
#
# - Imprimir el directorio de trabajo actual
# - Crear un directorio test1
# - No cambie de directorio, pero los items 4, 5 y 6 deben guardarse en el directorio creado en el paso 2.
# - Crear el archivo test1.txt
# - Guardar el texto Hola GBI6 en un archivo test2.txt
# - Guardar la instrucción print("Hola GBI6")  en el archivo test1.py
# Luego seleccione la instrucción que permite enlistar el contenido (incluyendo detalles) del directorio test1
#
# <img src="https://github.com/PECHE12/GBI6_Examenparcial1/blob/main/GBI6_Examenparcial1/Data/EJERCICIO2.jpeg"
#      ancho=600 alto=45/>
#
#
# ![EJERCICIO2.jpeg](attachment:8596f731-dab6-43cb-881c-c82c2c6f7557.jpeg)
# ## Ejercicio 3
# Para esta pregunta debe realizar previamente lo siguiente:
#
# - Imprimir el directorio de trabajo actual
# - Crear un directorio test1
# - No cambie de directorio, pero los items 4, 5 y 6 deben guardarse en el directorio creado en el paso 2.
# - Crear el archivo test1.txt
# - Guardar el texto Hola GBI6 en un archivo test2.txt
# - Guardar la instrucción print("Hola GBI6")  en el archivo test1.py
# - Luego seleccione la instrucción que imprima el número de elementos del directorio test1
#
# <img src="https://github.com/PECHE12/GBI6_Examenparcial1/blob/main/GBI6_Examenparcial1/Data/EJERCICIO3.jpeg"
# ancho=600 alto=45/>
#
# ![EJERCICIO3.jpeg](attachment:858adf68-c301-4fb4-a387-030179d20019.jpeg)
# ## Ejercicio 4
# Resuelva el ejercicio 1.10.1 Next Generation Sequencing Data.
#
# Resuelva el ejercicio en un documento de nombre ejercicio_1101.sh
# Cargue el documento ejercicio_1101.sh en GitHub utilizando git push.
# Realice el video explicativo de la resolución ejercicio y guarde en YouTube en formato "Público" o "Unlisted", y pegue el enlace en el cuaderno de Jupyter.
# La respuesta a este ejercicio es el enlace en GitHub de su archivo: ejercicio_1101.sh

# %% [markdown]
# # 3. INTRODUCCIÓN A PYTHON
#
# ## Ejercicio 5
# Resuelva el ejercicio 1.10.4 Data Explorer.
#
# Resuelva el ejercicio en un documento de nombre ejercicio_1104.sh
# Cargue el documento ejercicio_1104.sh en GitHub utilizando git push.
# Realice el video explicativo de la resolución ejercicio y guarde en YouTube en formato "Público" o "Unlisted", y pegue el enlace en el cuaderno de Jupyter.
# La respuesta a este ejercicio es el enlace en GitHub de su archivo: ejercicio_1104.sh
# Para este ejercicio tiene que crear previamente lo siguiente:
#
# ![EJERCICIO5.1.jpeg](attachment:3953c323-78cb-464d-ae78-9b7e3369a78c.jpeg)![EJERCICIO5.2.jpeg](attachment:622769b7-5c5b-4743-a15f-fed3ef9f9c23.jpeg)![EJERCICIO5.3.jpeg](attachment:f6d511fc-6682-42f6-a24a-e7007b1af44f.jpeg)

# %% [markdown]
# ![EJERCICIO6.jpeg](attachment:ec9fcac3-5c86-4309-aaba-4a9a09860ebe.jpeg)
#
# # 2. CONTROL DE LA VERSIÓN
# ## Pregunta 6
# Para este ejercicio tiene que crear previamente lo siguiente:
#
# Una lista de nombre lista1 que tenga a las 10 primeras letras del alfabeto.
# Relaciones los códigos y las respuestas que salen al ejecutar
#
#   lista1 = ["a", "b", "c", "d", "e", "f", "g", "h", "i", "j"]
# print(len(lista1)) # permite saber si tenemos las 10 letras
# print()
# print("inicia la corrida de códigos:")
# # Ejecucion de comandos pedidos en moodle
# lista1.append(["gbi6", "bio1", "ikiam"]) # se añade al final de la lista1 ["gbi6", "bio1", "ikiam"] como un solo dato
# print(lista1[-1][-1]) # devuelve "ikiam"
#
# lista1 = ["a", "b", "c", "d", "e", "f", "g", "h", "i", "j"] # Reestablecemos la lista1
# print(lista1[2:5]) # devuelve las letras encontradas entre las posiciones 2 y 5 sin tomar en cuenta el limite superior en este caso 5
#
# print(lista1[3]) # devuelve la letra encontrada en la posición 3
#
# lista1.append(["gbi6", "bio1", "ikiam"]) # inserta el elemento "gbi6", "bio1", "ikiam"] al final de la lista1
# print(len(lista1)) # imprime la longitud de la lista tras añadir el elemento anterior con append

# %% [markdown]
# # 2. CONTROL DE LA VERSIÓN
#
# ## Pregunta 7
# 1. Cada vez que resuelva un ejercicio (del 1 al 10), utilizando Git Bash, GitHub Desktop o Atom realice un *git push* con el mensaje:
#
#
# <font color='red'>Apellido Nombre ha resuelto el ejercicio 1</font> % Cambie con sus apellidos y nombres; y con el número de ejercicio que corresponda
#
# 2. Coloque aquí las capturas de pantalla para cada git push realizado desde Git Bash, GitHub Desktop o Atom.
#
# - Control de versión ejercicio 1
#
# <img src="data/ejemplo_unix.jpg" width=600 height=450 />
#
# - Control de versión ejercicio 2
#
# <img src="data/ejemplo_unix.jpg" width=600 height=450 />
#
# - Control de versión ejercicio 3
#
# <img src="data/ejemplo_unix.jpg" width=600 height=450 />
#
# - Control de versión ejercicio 4
#
# <img src="data/ejemplo_unix.jpg" width=600 height=450 />
#
# - Control de versión ejercicio 5
#
# <img src="data/ejemplo_unix.jpg" width=600 height=450 />
#
# - Control de versión ejercicio 8
#
# <img src="data/ejemplo_unix.jpg" width=600 height=450 />
#
# - Control de versión ejercicio 9
#
# <img src="data/ejemplo_unix.jpg" width=600 height=450 />
#
# - Control de versión ejercicio 10
#
# <img src="data/ejemplo_unix.jpg" width=600 height=450 />
#
#
# 3. Cree un directorio de nombre ```data``` donde deben estar guardados: (i) la data utilizada y (ii) las capturas de pantalla de los ejercicios 1 al 3 y los git push del ejercicio 1 al 10 (en total debe tener 13 imágenes).
# 4. Inserte aquí el enlace de su repositorio (válido para el ejercicio 6 y 7): [GitHub Repository: GBI6_ExamenParcial1](https://github.com/gualapuromoises/2021_gbi6.git) (este enlace es de ejemplo)

# %%
# Escriba aquí el código

# %% [markdown]
# ## Ejercicio 7
#
# Para este ejercicio tiene que crear previamente lo siguiente:
#
# En la data https://github.com/sap0408/mtcars/blob/master/mtcars.csv, seleccione los 10 primeros registros y cree una lista de nombre lista1.
#
# Relaciones los códigos y las respuestas que salen al ejecutar.

# %%
# 
lista1 =["Mazda RX4", "Mazda RX4 Wag", "Datsun 710", "Hornet 4 Drive", "Hornet Sportabout", "Valiant", "Duster 360", "Merc 2400", "Merc 230", "Merc 280"]
lista1.append(["gbi6", "bio1", "ikiam"])
print(lista1[-1][-3])

lista1 =["Mazda RX4", "Mazda RX4 Wag", "Datsun 710", "Hornet 4 Drive", "Hornet Sportabout", "Valiant", "Duster 360", "Merc 2400", "Merc 230", "Merc 280"]
print(lista1[2:5])

print(lista1[4])

print(lista1[3])

lista1.append(["gbi6", "bio1", "ikiam"])
print(len(lista1))

# %% [markdown]
# ## Ejercicio 8
#
# Para este ejercicio debe debe realizar lo siguiente:
#
# Crear un diccionario de nombre dic_aminoacidos, donde se tenga la información de la tabla que se encuentra en http://www.russelllab.org/aas/aas.html.
# Utilice como "key" los valores de la columna "AA" y las columnas "Hits" y "%Abundance" como "values".
# Luego de crear el diccionario, extraiga los valores de "key" a una lista de nombre "aminoacidos"
# Extraiga los valores de "value" a una lista de nombre "propiedades"
# Para evaluar esta pregunta realice un git push del Jupyter Notebook al repositorio del examen.
#
# ![Ejercicio8.jpeg](attachment:de1b6431-06fb-44d0-aa30-baf2c1abaeb9.jpeg)

# %%
# winpty python
>>> dic_aminoacidos = {"Trp": [1550, 1.34, ],"Cys": [1905, 1.76, ],"His": [1695,
 2.26, ],"Arg": [3093, 5.20, ],"Met": [1102, 2.32, ],"Tyr": [1525, 3.25, ],"Gln"
: [1830, 3.96, ],"Phe": [1616, 4.12, ],"Asp": [1691, 5.12, ],"Pro": [1598, 5.00,
 ],"Ala": [2018, 7.34, ],"Asn": [1103, 4.57, ],"Lys": [1366, 5.81, ],"Glu": [147
1, 6.22, ],"Gly": [1376, 6.89, ],"Thr": [1147, 5.85, ],"Val": [1225, 6.48, ],"Il
e": [1033, 5.76, ],"Ser": [1206, 7.38, ],"Leu": [1127, 9.36, ],}
>>> print ("Este es el diccionario dic_aminoacidos:")
>>> aminoacidos =list(dic_aminoacidos.keys())
>>> print()

>>> print("esta es la lista de aminoacidos:",aminoacidos")
  
>>> print("esta es la lista de aminoacidos:",aminoacidos)
>>> propiedades =list(dic_aminoacidos.values())
>>> print()

>>> print("esta es la lista propiedades:",propiedades)
